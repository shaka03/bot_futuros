# %% [markdown]
# ### **Librerías**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Parámetros**

# %%
os.chdir("/Users/juanchacon/Library/Mobile Documents/com~apple~CloudDocs/GitHub/bot_futuros")

SILVER_DATA_PATH = os.getcwd() + "/data/silver/"

dict_files = {
    "futuros": "precios_FUTUROS.csv",
    "precios": "datos_PRECIOS.csv",
    "precios_ponderados": "datos_PRECIOS_PONDERADOS.csv",
    "demanda": "datos_DEMANDA.csv",
    "demanda_comprador": "datos_DEMANDA_COMPRADOR.csv",
    "aportes_hidricos": "datos_APORTES_HIDRICOS.csv",
    "niveles_embalse": "datos_NIVELES_EMBALSE.csv",
    "generacion": "datos_GENERACION_REAL.csv",
    "disponibilidad": "datos_DISPONIBILIDAD_REAL.csv",
}

start_date = "2024-01-01"
end_date = "2026-01-31"

# %% [markdown]
# ### **EDA**

# %% [markdown]
# #### **Futuros**

# %%
# Carga de datos
df_futuros = pd.read_csv(SILVER_DATA_PATH + dict_files["futuros"])

# Revisar las primeras filas del DataFrame
display(df_futuros.head())
# Out:
#   Nemotecnico Tipo    Mes   Año       Fecha  Precio
# 0     ELMF26F  ELM  Enero  2026  2026-01-02  390.05
# 1     ELMF26F  ELM  Enero  2026  2026-01-05  386.97
# 2     ELMF26F  ELM  Enero  2026  2026-01-06  383.41
# 3     ELMF26F  ELM  Enero  2026  2026-01-07  379.84
# 4     ELMF26F  ELM  Enero  2026  2026-01-08  374.07

# %%
# Revisar la estructura del DataFrame
df_futuros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74736 entries, 0 to 74735
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nemotecnico  74736 non-null  object
#  1   Tipo         74736 non-null  object
#  2   Mes          74736 non-null  object
#  3   Año          74736 non-null  int64
#  4   Fecha        74736 non-null  object
#  5   Precio       74736 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.4+ MB
