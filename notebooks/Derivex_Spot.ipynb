# %% [markdown]
# <a id='section1'></a>
# # Instalación de la librería
# Ejecutar el siguiente comando en el CMD para instalar la librería de python.

# %%
#pip install pydataxm

# %% [markdown]
# <a id='section2'></a>
# # Importación de librerías

# %%
from pydataxm.pydatasimem import CatalogSIMEM, ReadSIMEM
import datetime as dt
import pandas as pd

# %%
# Buscar dataset
cat = CatalogSIMEM('Datasets')
df_cat = cat.get_data()
df_cat[df_cat['nombreConjuntoDatos'].str.contains('bolsa', case=False)]
# Out:
#     idDataset                                nombreConjuntoDatos  \
# 4      B1009C               Compras en bolsa nacional en energía
# 52     1E0AC7                    Compras en bolsa TIE en energía
# 188    709b84                   Precio de Transacciones en Bolsa
# 193    6D6E23           Ventas en bolsa internacional en energía
# 214    EC6945                            Precio de bolsa horario
# 253    615509                       PrecioBolsaPromedioPonderado
# 280    b94b3c  Limitación de suministro en bolsa según la Res...
# 311    A88E47                     Ventas en bolsa TIE en energía
# 348    4295B4          Compras en bolsa internacional en energía
# 378    96D56E                          Precio de bolsa ponderado
# 407    F387F3                Ventas en bolsa nacional en energía
#
#             fechaPublicacion       fechaActualizacion           inicioDato  \
# 4    2024-11-07T10:33:56.017  2025-09-30T09:21:26.783  2021-01-01T00:00:00
# 52   2024-11-07T10:33:56.017  2025-09-30T09:20:29.403  2021-01-01T00:00:00
# 188  2025-03-06T09:13:54.037  2025-09-30T09:21:34.717  2024-09-01T00:00:00
# 193  2024-11-07T10:33:56.017   2025-09-30T09:21:29.63  2021-01-01T00:00:00
# 214   2023-10-02T21:36:52.81   2025-09-30T09:22:33.09  2013-01-01T00:00:00
# 253    2025-07-07T14:19:42.1  2025-09-24T11:34:38.607  2024-10-01T00:00:00
# 280   2023-09-29T21:57:06.05   2025-09-30T07:21:23.84  2013-02-15T00:00:00
# 311  2024-11-07T10:33:56.017  2025-09-30T09:22:05.453  2021-01-01T00:00:00
# 348  2024-11-07T10:33:56.017  2025-09-30T09:22:29.823  2021-01-01T00:00:00
# 378   2023-10-03T15:00:21.54  2025-09-30T09:30:29.147  2013-01-01T00:00:00
# 407  2024-11-07T10:33:56.017  2025-09-30T09:26:11.207  2021-01-01T00:00:00
#
#                  finDato            fechaDescarga  \
# 4    2025-09-05T00:00:00                     None
# 52   2025-09-05T00:00:00                     None
# 188  2025-09-25T00:00:00  2025-05-07T12:09:55.257
# 193  2025-09-07T00:00:00                     None
# 214  2025-09-27T00:00:00  2025-05-06T09:29:49.443
# 253  2025-08-31T00:00:00                     None
# 280  2025-09-26T00:00:00   2025-04-22T08:15:24.74
# 311  2025-09-07T00:00:00                     None
# 348  2025-09-05T00:00:00                     None
# 378  2025-09-27T00:00:00  2025-05-04T22:01:32.183
# 407  2025-09-25T00:00:00                     None
#
#                                         urlConexionAPI  \
# 4    https://www.simem.coPublicData?startDate=2025-...
# 52   https://www.simem.coPublicData?startDate=2025-...
# 188  https://www.simem.coPublicData?startDate=2025-...
# 193  https://www.simem.coPublicData?startDate=2025-...
# 214  https://www.simem.coPublicData?startDate=2025-...
# 253  https://www.simem.coPublicData?startDate=2025-...
# 280  https://www.simem.coPublicData?startDate=2025-...
# 311  https://www.simem.coPublicData?startDate=2025-...
# 348  https://www.simem.coPublicData?startDate=2025-...
# 378  https://www.simem.coPublicData?startDate=2025-...
# 407  https://www.simem.coPublicData?startDate=2025-...
#
#                                       urlConjuntoDatos tipoPublicacion
# 4    https://www.simem.co/datadetail/b1009c18-5450-...         Público
# 52   https://www.simem.co/datadetail/1e0ac7d3-2c0a-...         Público
# 188  https://www.simem.co/datadetail/839a62cd-1d50-...         Público
# 193  https://www.simem.co/datadetail/6d6e23e5-cfd3-...         Público
# 214  https://www.simem.co/datadetail/ec694552-8887-...         Público
# 253  https://www.simem.co/datadetail/615509d5-701e-...         Público
# 280  https://www.simem.co/datadetail/b94b3c99-857b-...         Público
# 311  https://www.simem.co/datadetail/a88e4711-493c-...         Público
# 348  https://www.simem.co/datadetail/4295b42c-6d59-...         Público
# 378  https://www.simem.co/datadetail/96d56e82-11cb-...         Público
# 407  https://www.simem.co/datadetail/f387f353-200f-...         Público

# %%
# Descargar
id_dataset = "EC6945"
fecha_inicio_str = "2015-01-01"
fecha_inicio = dt.datetime.strptime(fecha_inicio_str, "%Y-%m-%d")
fecha_fin_str = "2025-09-30"
fecha_fin = dt.datetime.strptime(fecha_fin_str, "%Y-%m-%d")
list_df = []
keep = True

while keep:
    fecha_part = dt.datetime(fecha_inicio.year, 12, 31)
    fecha_part_str = dt.datetime.strftime(fecha_part, "%Y-%m-%d")
    print(f"{fecha_inicio_str} a {fecha_part_str}")
    if fecha_part >= fecha_fin:
        reader = ReadSIMEM(id_dataset, fecha_inicio_str, fecha_fin_str)
        keep = False
    else:
        reader = ReadSIMEM(id_dataset, fecha_inicio_str, fecha_part_str)
    
    df = reader.main(filter=False)
    df = df[df['CodigoVariable'] == 'PB_Nal']
    list_df.append(df)
    del df

    fecha_inicio = dt.datetime(fecha_inicio.year + 1, 1, 1)
    fecha_inicio_str = dt.datetime.strftime(fecha_inicio, "%Y-%m-%d")
# Out:
# 2015-01-01 a 2015-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0010020732879638672
# Extraccion de registros: 74.48386979103088
# End of data extracting process
# ****************************************************************************************************
# 2016-01-01 a 2016-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0008471012115478516
# Extraccion de registros: 55.51651096343994
# End of data extracting process
# ****************************************************************************************************
# 2017-01-01 a 2017-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.00074005126953125
# Extraccion de registros: 54.85504198074341
# End of data extracting process
# ****************************************************************************************************
# 2018-01-01 a 2018-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0007100105285644531
# Extraccion de registros: 52.80686402320862
# End of data extracting process
# ****************************************************************************************************
# 2019-01-01 a 2019-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0005450248718261719
# Extraccion de registros: 50.84695601463318
# End of data extracting process
# ****************************************************************************************************
# 2020-01-01 a 2020-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0006580352783203125
# Extraccion de registros: 50.953097105026245
# End of data extracting process
# ****************************************************************************************************
# 2021-01-01 a 2021-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.00078582763671875
# Extraccion de registros: 52.885448932647705
# End of data extracting process
# ****************************************************************************************************
# 2022-01-01 a 2022-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0007050037384033203
# Extraccion de registros: 54.76621985435486
# End of data extracting process
# ****************************************************************************************************
# 2023-01-01 a 2023-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0007157325744628906
# Extraccion de registros: 51.14032006263733
# End of data extracting process
# ****************************************************************************************************
# 2024-01-01 a 2024-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.0004448890686035156
# Extraccion de registros: 53.87249422073364
# End of data extracting process
# ****************************************************************************************************
# 2025-01-01 a 2025-12-31
# ****************************************************************************************************
# Initializing object
# The object has been initialized with the dataset: "Precio de bolsa horario"
# ****************************************************************************************************
# Inicio consulta sincronica
# Creacion url: 0.000637054443359375
# Extraccion de registros: 39.186732053756714
# End of data extracting process
# ****************************************************************************************************

# %%
df = pd.concat(list_df)
df.to_csv("Precio_Energia.csv", index=False, sep=",")
